# %%
import os
import combine_modules
import matplotlib.pyplot as plt

# %%
run = 351
c = combine_modules.AGIPD_Combiner(run,geom_fname='../geometry/agipd_2696_v5.geom')
# Out:
# Not all modules have the same frames
# [1052128 1054240 1055648 1060224 1046848 1052480 1053184 1054592 1051072
#  1052832 1054592 1060224 1053536 1054944 1051424 1050368]
# 1060224 good frames in run

# %%
frame = c.get_frame(1000)

# %%
plt.figure(figsize=(10,10))
plt.imshow(frame.transpose())
